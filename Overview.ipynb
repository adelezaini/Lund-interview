# %%
import numpy as np
import xarray as xr

# %%
fn = 'hfls_AFR-44_CanESM_VegFB_v2_SMHI-RCA4_v1_mon_201601-202012.nc'
hfls = xr.open_dataset(fn)

fn = 'pr_AFR-44_CanESM_VegFB_v2_SMHI-RCA4_v1_mon_201601-202012.nc'
pr = xr.open_dataset(fn)

# %%
pr
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 60, bnds: 2, rlat: 201, rlon: 194)
# Coordinates:
#   * time          (time) object 2016-01-16 12:00:00 ... 2020-12-16 12:00:00
#     lon           (rlat, rlon) float64 ...
#     lat           (rlat, rlon) float64 ...
#   * rlon          (rlon) float64 -24.64 -24.2 -23.76 -23.32 ... 59.4 59.84 60.28
#   * rlat          (rlat) float64 -45.76 -45.32 -44.88 ... 41.36 41.8 42.24
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds     (time, bnds) object ...
#     rotated_pole  int32 ...
#     pr            (time, rlat, rlon) float32 ...
# Attributes: (12/21)
#     CDI:                            Climate Data Interface version 1.9.9rc1 (...
#     Conventions:                    CF-1.4
#     history:                        Tue May 23 11:59:08 2023: cdo seltimestep...
#     contact:                        minchaowu.acd@gmail.com
#     experiment:                     Simulation with vegetation feedback
# ...

# %%
hfls
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 60, bnds: 2, rlat: 201, rlon: 194)
# Coordinates:
#   * time          (time) object 2016-01-16 12:00:00 ... 2020-12-16 12:00:00
#     lon           (rlat, rlon) float64 ...
#     lat           (rlat, rlon) float64 ...
#   * rlon          (rlon) float64 -24.64 -24.2 -23.76 -23.32 ... 59.4 59.84 60.28
#   * rlat          (rlat) float64 -45.76 -45.32 -44.88 ... 41.36 41.8 42.24
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds     (time, bnds) object ...
#     rotated_pole  int32 ...
#     hfls          (time, rlat, rlon) float32 ...
# Attributes: (12/21)
#     CDI:                            Climate Data Interface version 1.9.9rc1 (...
#     Conventions:                    CF-1.4
#     history:                        Tue May 23 11:23:17 2023: cdo seltimestep...
#     contact:                        minchaowu.acd@gmail.com
#     experiment:                     Simulation with vegetation feedback
# ...

# %%
hfls['hfls'].plot(y='rlat', x='rlon', col='time', col_wrap=6)

# %%
obs_2016
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 900, latitude: 451, time: 12)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.6 -179.2 ... 178.8 179.2 179.6
#   * latitude   (latitude) float32 90.0 89.6 89.2 88.8 ... -89.2 -89.6 -90.0
#   * time       (time) datetime64[ns] 2016-01-02 2016-02-02 ... 2016-12-02
# Data variables:
#     slhf       (time, latitude, longitude) float32 ...
#     e          (time, latitude, longitude) float32 ...
#     ro         (time, latitude, longitude) float32 ...
#     tp         (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-05-25 16:02:53 GMT by grib_to_netcdf-2.26.0: grib_to_n...

# %%
obs_2016['slhf'].isel(time=0).plot(y='latitude', x='longitude')
